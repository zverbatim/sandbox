# %%
# tutorial based of http://www.nltk.org/book/ch01.html

from nltk.book import *
import  matplotlib.pyplot as plt

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
# concordance  - view the text inside the context
text1.concordance('excellent')
# Out:
# Displaying 12 of 12 matches:
# as his head was phrenologically an excellent one . It may seem ridiculous , but
# unconquerable warriors . There was excellent blood in his veins -- royal stuff
# and the chowder being surpassingly excellent , we despatched it with great expe
# . But it was startling to see this excellent hearted Quakeress coming on board
# trary . His pure tight skin was an excellent fit ; and closely wrapped up in it
# ; but so far as it goes , it is of excellent quality , though mostly confined t
# s . I mean no disparagement to the excellent voyager ( I honour him for a veter
# s always replenished with the most excellent of the wines of the Rhenish valley
#  ! happy that the world is such an excellent listener ! Now , the spouting cana
#  recognised by the fishermen as an excellent spot for cruising ; therefore , as
# lish whalers have not neglected so excellent an example . For , say they , when
# ...

# %%
text1.similar('good')
# Out:
# great much large small the in it that long white common old with whale
# well certain close such important considerable

# %%
text2.similar('good')
# Out:
# large short long young great much comfortable kind quiet pretty
# charming in respectable as to house one that time thing

# %%
context = ["very", "monstrous"]
text1.common_contexts(context)
print('--')
text2.common_contexts(context)
# Out:
# No common contexts were found
# --
# is_pretty a_pretty be_glad am_glad a_lucky

# %%
# dispersion plot - shows word occurence
words = ["citizens", "democracy", "freedom", "duties", "America"]
text4.dispersion_plot(words)

# %%
sorted(set(text3))[25:35]
# Out:
# ['Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah']

# %%
# number of distinct words
len (set(text4)) / len(text4) * 100
# Out:
# 6.692970116993173

# %%
text4.count('country')
# Out:
# 296

# %%
text5.count('the')
# Out:
# 646

# %%
text5.count(':)')
# Out:
# 101

# %%
text5.count(':-)')
# Out:
# 27

# %%
text4.index('president')
# Out:
# 135994

# %%
text4[135994-10:135994+10]
# Out:
# ['ask',
#  'the',
#  'congress',
#  'to',
#  'join',
#  'with',
#  'me',
#  ';',
#  'but',
#  'no',
#  'president',
#  ',',
#  'no',
#  'congress',
#  ',',
#  'no',
#  'government',
#  'can',
#  'undertake',
#  'THIS']

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done','more', 'is', 'said', 'than', 'done']
tokens = sorted(set(saying))

# %%
tokens
# Out:
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']

# %%
tokens[-2:]
# Out:
# ['said', 'than']

# %%
# word frequency using this function. Returns a dictionary
fd = FreqDist(text4)

# %%
print(fd)
# Out:
# <FreqDist with 9754 samples and 145735 outcomes>

# %%
fd
# Out:
# FreqDist({'Fellow': 24,
#           '-': 280,
#           'Citizens': 7,
#           'of': 6970,
#           'the': 9281,
#           'Senate': 11,
#           'and': 4991,
#           'House': 8,
#           'Representatives': 5,
#           ':': 124,
#           'Among': 4,
#           'vicissitudes': 5,
#           'incident': 8,
#           'to': 4311,
#           'life': 133,
#           'no': 406,
#           'event': 16,
#           'could': 69,
#           'have': 994,
#           'filled': 6,
#           'me': 186,
#           'with': 886,
#           'greater': 52,
#           'anxieties': 3,
#           'than': 234,
#           'that': 1688,
#           'which': 1002,
#           'notification': 1,
#           'was': 268,
#           'transmitted': 3,
#           'by': 1036,
#           'your': 104,
#           'order': 64,
#           ',': 6840,
#           'received': 12,
#           'on': 496,
#           '14th': 1,
#           'day': 87,
#           'present': 85,
# ...

# %%
len(text4)
# Out:
# 145735

# %%
type(fd)
# Out:
# nltk.probability.FreqDist

# %%
fd.plot(50, cumulative=True)
plt.show()

# %%
# words that pop only once
fd.hapaxes()[:10]
# Out:
# ['notification',
#  '14th',
#  'fondest',
#  'predilection',
#  'flattering',
#  'asylum',
#  'interruptions',
#  'awaken',
#  'distrustful',
#  'despondence']

# %%
# words longer than 20 chars
longer_20 = [w for w in text5 if len(w) > 20]

# %%
longer_20[:5]
# Out:
# ['iamahotnipwithhotnippics',
#  '..............................',
#  'mikeeeeeeeeeeeeeeeeeeeeeeeeee',
#  'oooooooooooooonnnnnnnnnnnneeeeeeeeeeeeeeesssssssss',
#  '!!!!!!!!!!!!!!!!!!!!!!!']

# %%
# filter out based of freq and len
longer_10_freq_5 = [w for w in set(text4) if len(w) > 10 and fd[w] > 5]

# %%
longer_10_freq_5[:10]
# Out:
# ['illustrious',
#  'differences',
#  'declaration',
#  'opportunity',
#  'recognition',
#  'citizenship',
#  'civilization',
#  'satisfactory',
#  'consequence',
#  'contemplate']

# %%
#collocation is a sequence of words that occur together unusually often
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
fd.freq('president')
# Out:
# 6.861769650392836e-06

# %%
fd.N()
# Out:
# 145735

# %%
fd.most_common()
# Out:
# [('the', 9281),
#  ('of', 6970),
#  (',', 6840),
#  ('and', 4991),
#  ('.', 4676),
#  ('to', 4311),
#  ('in', 2527),
#  ('a', 2134),
#  ('our', 1905),
#  ('that', 1688),
#  ('be', 1460),
#  ('is', 1403),
#  ('we', 1141),
#  ('for', 1075),
#  ('by', 1036),
#  ('it', 1011),
#  ('which', 1002),
#  ('have', 994),
#  ('not', 916),
#  ('as', 888),
#  ('with', 886),
#  ('will', 846),
#  ('I', 831),
#  ('are', 774),
#  ('all', 758),
#  ('their', 719),
#  ('this', 700),
#  ('The', 619),
#  ('has', 611),
#  ('people', 559),
#  ('its', 554),
#  (';', 544),
#  ('or', 537),
#  ('from', 521),
#  ('on', 496),
#  ('We', 483),
#  ('been', 482),
#  ('but', 479),
#  ('can', 457),
#  ('us', 455),
#  ('my', 449),
#  ('no', 406),
#  ('an', 377),
#  ('--', 363),
#  ('upon', 363),
#  ('who', 356),
#  ('It', 356),
#  ('so', 354),
#  ('must', 345),
#  ('they', 341),
#  ('Government', 331),
#  ('them', 327),
#  ('States', 325),
#  ('should', 318),
#  ('may', 316),
#  ('at', 316),
#  ('great', 312),
# ...

# %%
fd.max()
# Out:
# 'the'

# %%
[w for w in text1 if w.istitle()][:10]
# Out:
# ['Moby',
#  'Dick',
#  'Herman',
#  'Melville',
#  'Supplied',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'Grammar',
#  'School']

# %%
[w for w in text1 if w.isdigit()][:10]
# Out:
# ['1851', '890', '1671', '1652', '500', '1668', '1729', '1772', '1778', '40']
